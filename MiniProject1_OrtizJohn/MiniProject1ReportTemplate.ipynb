# %% [markdown]
# # Mini Project 1 Report

# %% [markdown]
# Your name: `John Ortiz`

# %%
# %matplotlib inline
import math 
from curveFitting import one_dimensional_curve_fitting_test

# %% [markdown]
# ## Benchmarking

# %% [markdown]
# - Attempt these problems only after you have finished and tested your implementation.
# - If you modify any of the python files, remember to "restart the kernel" or else the changes will not take effect.
# - We have provided 5 tests below. For each test, run it 5 different times and record the best solution/fitness for each trial along with the run time.
# - You will need to modify the code below, perhaps adding some nice print statements or adding your results to a table.

# %%
for i in range(5): #Test1 ->in table
    one_dimensional_curve_fitting_test(lambda x: 0.2*math.exp(x/4.0) -  math.sin(2*x)  , (-10.0, 10.0), 25)
# Out:
# GA Returned Solution: sin((x/-0.5)) with fitness -8.06813776185479
# GA Returned Solution: (sin(x) - -0.8116807265414194 * 0.5) with fitness -14.430498832217173
# GA Returned Solution: cos((x + x + 1.5)) with fitness -9.542226775903165
# GA Returned Solution: sin((x/-0.5)) with fitness -7.768856476951943
# GA Returned Solution: sin(((x + x + 2.0) + (cos((x + x + -16.619707775821773)) + 1.0))) with fitness -5.583786139344742

# %%
for i in range(5): #Test2 ->in table
    one_dimensional_curve_fitting_test(lambda x: math.sin(2*x) - math.cos(3*x-1) + 2*math.sin(x/2+1.0)  , (-15.0, 15.0), 60)
# Out:
# GA Returned Solution: ((cos((x - 1.0 * -0.5))/cos(cos(cos(((x/-2.0) + 0.5919660684436714)))))/0.5919660684436714) with fitness -52.13373383810338
# GA Returned Solution: (sin((x - -0.5 + (x/-2.0))) + cos(((x - -0.5/-2.0) + x))) with fitness -59.57566951632298
# GA Returned Solution: sinh(cos(((x * -0.5) + 0.5))) with fitness -75.6349712307653
# GA Returned Solution: sin(((x/2.0) + 0.951660245428088)) with fitness -120.23842486417531
# GA Returned Solution: cos(((x * -0.5) + 0.6579307818659732)) with fitness -106.69501176406395

# %%
for i in range(5):#Test3 ->in table
    one_dimensional_curve_fitting_test(lambda x: math.exp(math.sin(2*x)) - math.exp(math.cos(3*x))  , (-15.0, 15.0), 60)
# Out:
# GA Returned Solution: sin((x + x) - cos(x)) with fitness -42.64616392411928
# GA Returned Solution: sin(((x + 0.5) + x - cos(x))) with fitness -31.427727257491398
# GA Returned Solution: sin((x * 2.0)) - cos((x + x + x)) with fitness -6.525692164528559
# GA Returned Solution: sinh(sin((x/0.5) - cos(x))) with fitness -27.347627954605155
# GA Returned Solution: sin((x/0.5) - cos(x)) with fitness -28.36548106630797

# %%
for i in range(5):#Test4 ->in table
    one_dimensional_curve_fitting_test(lambda x: 0.05*x**2 - 0.5*x + 5.0 * math.sin(3*x) , (-15.0, 15.0), 60)
# Out:
# GA Returned Solution: exp(((x/-2.0) * 0.4450853368470909)) with fitness -1025.200857827933
# GA Returned Solution: (sqrt((x * (x/2.0) * 0.5)) + (x/2.0) + (x * -1.0)) with fitness -794.0679740255727
# GA Returned Solution: (cos(atan(exp((x + -3.6924997795353356) - 1.0))) * x - (x + x + -1.8462498897676678)) with fitness -856.683784886787
# GA Returned Solution: tanh(((x + -4.284562238202529) - ((-3.784562238202529)/-2.0) * x)) - ((x + -4.284562238202529) - 1.0 * 0.5) with fitness -998.3631586980014
# GA Returned Solution: ((((exp(x) + x) * x) * atan(atan(x)))/(exp((x + x)) + x)) with fitness -901.6511017797013

# %%
for i in range(5):#Test5 ->in table
    one_dimensional_curve_fitting_test(lambda x: 0.05*x**2 - 0.5*math.sqrt(x) + 5.0 * math.sin(3*x) , (0.0, 15.0), 30)
# Out:
# GA Returned Solution: log((cosh(x - 2.0)/(cos((x + x + x + 2.0)) - 2.0 + x + 4.0))) - cos((x + x + x + 2.0)) with fitness -210.2343712744721
# GA Returned Solution: exp((((x * x * 0.5)/(((x + (x + x + x + -0.5)) + 2.0) + 2.0)) + sin((x + x + x + -0.5)))) with fitness -115.13270394365085
# GA Returned Solution: (((x * x * 0.5)/(x + x + -3.9245704832862582)) * atan(x) * 0.9092974268256817) with fitness -356.5682090095939
# GA Returned Solution: ((x + -2.0) + 0.7853981633974483) - sqrt((x + x + x + atan(x) + 1.0)) with fitness -336.0871218005243
# GA Returned Solution: (cos(((x + 2.0)/-2.5)) + ((x * 0.9092974268256817)/(2.5)) + -0.8414709848078965) with fitness -366.2149815700143

# %% [markdown]
# `Put your table with results here!` You may [create a table using markdown](https://www.tablesgenerator.com/markdown_tables) (below) or print a nicely formatted table using a library such as Pandas.
#
# - Test1 $\to$ (lambda x: 0.2*math.exp(x/4.0) -  math.sin(2*x)  , (-10.0, 10.0), 25)
# - Test2 $\to$ (lambda x: math.sin(2*x) - math.cos(3*x-1) + 2*math.sin(x/2+1.0)  , (-15.0, 15.0), 60)
# - Test3 $\to$ (lambda x: math.exp(math.sin(2*x)) - math.exp(math.cos(3*x))  , (-15.0, 15.0), 60)
# - Test4 $\to$ (lambda x: 0.05*x**2 - 0.5*x + 5.0 * math.sin(3*x) , (-15.0, 15.0), 60)
# - Test5 $\to$ (lambda x: 0.05*x**2 - 0.5*math.sqrt(x) + 5.0 * math.sin(3*x) , (0.0, 15.0), 30)
#
# Note to make these more legible I rounded all numbers to two decimals.
#
#
# | Test1  |Test2|Test3|
# |  ---   |---  |  --- |
# |   (sin((x/-0.5)),-8.06)   | (((cos((x - 1.0 * -0.5))/cos(cos(cos(((x/-2.0) + 0.59)))))/0.59) ,-52.13) |  (sin((x + x) - cos(x)),-42.64)
# |  ((sin(x) - -0.81 * 0.5),-14.43)   | ((sin((x - -0.5 + (x/-2.0))) + cos(((x - -0.5/-2.0) + x))) ,-59.58 )  | (sin(((x + 0.5) + x - cos(x))),-31.42)
# |  (cos((x + x + 1.5)),-9.54)   | (sinh(cos(((x * -0.5) + 0.5))), -75.63)  | (sin((x * 2.0)) - cos((x + x + x)),-6.52)
# |  (sin((x/-0.5)),-7.76)   | (sin(((x/2.0) + 0.95)) , -120.23)  |  (sinh(sin((x/0.5) - cos(x))),-27.34)
# |  (sin(((x + x + 2.0) + (cos((x + x + -16.62)) + 1.0))),-5.58)   | ( cos(((x * -0.5) + 0.65)),-106.69 ) |  (sin((x/0.5) - cos(x)),-28.36)
#
#
#
# | Test4   |  Test5 |
# |---  |---  |
# | (exp(((x/-2.0) * 0.44)),-1025.20)  |  (log((cosh(x - 2.0)/(cos((x + x + x + 2.0)) - 2.0 + x + 4.0))) - cos((x + x + x + 2.0)),-210.23) |
# | ((sqrt((x * (x/2.0) * 0.5)) + (x/2.0) + (x * -1.0)),-794.06)  |  (exp((((x * x * 0.5)/(((x + (x + x + x + -0.5)) + 2.0) + 2.0)) + sin((x + x + x + -0.5)))),-115.13) |
# | ((cos(atan(exp((x + -3.69) - 1.0))) * x - (x + x + -1.84)),-856.68)  |  ((((x * x * 0.5)/(x + x + -3.92)) * atan(x) * 0.90),-356.56) |
# | (tanh(((x + -4.28) - ((-3.78)/-2.0) * x)) - ((x + -4.28) - 1.0 * 0.5),-998.36)  |  (((x + -2.0) + 0.78) - sqrt((x + x + x + atan(x) + 1.0)),-336.08) |
# | (((((exp(x) + x) * x) * atan(atan(x)))/(exp((x + x)) + x)),-901.65)  |  ((cos(((x + 2.0)/-2.5)) + ((x * 0.90)/(2.5)) + -0.84),-366.21) |

# %% [markdown]
# Write a brief analysis of your results. Some questions to answer:
# - Which problem ran the fastest? Why do you think this is the case?
# - Which problem ended with the highest fitness? Why do you think this is the case?
# - How similar were the running times across the 5 repetitions?
# - How similar were the final fitness scores across the 5 repetitions?
# - Was there anything else interesting in your results?

# %% [markdown]
# Test1 ran the fastest in terms of finding a local maximum.Three out of of the trials hit a local max after 1 iteration. I think test1 function was found the fasted because there is only 1 sin and one exponential which is only two terms compared to all the other tests.Again problem1 (test1) had the highest fitness reiterating the fact that it was the least complex expression. Below are my eyeballed recording of where each repition flattend out(found local max - based on second diagram).
#
# |Repetition  | Test1  |Test2 |Test3 |Test4|Test5 |
# |  ---   |  ---   |---   |  --- |---  |  --- |
# | 1      |1     |    10|12    |    4|    12|
# | 2      |10      |    1|2    |    10|    10|
# | 3      |1      |    8|2    |    10|    6|
# | 4      |1      |    2|8    |    4|    6|
# | 5      |5      |    2|12    |    4|    4|
#
# For each problem(test), the final fitness scores seem to fit into a small range. For instance test1 fitnesses were all between (-15,-5), as like test5 fitness range were all inbetween (-366,-115). The only other thing that stood out to me is in Test1 there was two outputs with the same expression, but different fitnesses. (Bug?)

# %% [markdown]
# ## Describe Your Implementation and Reflect

# %% [markdown]
# Some questions to answer in your write-up:
# - What was your strategy to solve this problem?
# - How did you structure your `GASolver` class?
# - What other files or methods did you change?
# - What was the most difficult part of the project?
# - What was something surprising you found?
#
# Please provide some elaboration with your answers. When describing your implementation, remember that we have not watched you solve this problem so you will need to give more details than you think is necessary.

# %% [markdown]
# My strategy is the same with most homeworks but it always starts by breaking down each specific problem into smaller ones. The only changes I made to the structure is adding more functions to it. I added a helper for sorting the population by fitness. I made the best decision in building a helper for printing the population and fitness(best for debugging). I also implemented a weight helper function that would output the weights based on current population and fitness. It was helpful to keep my single iteration helper function not have to much code. That aforementioned singleIteration helper function is where the genetic algorithms "transition" from one generation to the next is. I split in to two parts like the project suggest two. I first grabbed the elites by using my sorting function than grabbing them with a for loop. The next part I thought was the hardest of the project: finding n-k cross-mutated expressions. I again broke it further down of just getting two expressions as another function. So for the first expression, I used the self.choices and the weights from my helper function, but I kept k(size of the return list) to 1. I did this to change the weight value of e1 in the weight list to zero for the second call to random.choice for e2. This way I did not have replacement. After that it was pretty self explanatory by just using the functions given. There were no other files or methods I changed. Something surprising I found was how all results have pretty good fitness scores, but some of the actual lines I would not consider 'good' fits.

# %% [markdown]
# ## Going Above and Beyond

# %% [markdown]
# Describe the extra changes you implemented. Give some details, perhaps a short paragraph for each major change.

# %% [markdown]
# `Your answer here.`

# %% [markdown]
# Describe the analysis you did and provide your results in the form of a figure or a table.

# %% [markdown]
# `Your answer here.`

# %% [markdown]
# Reflect on your work for this section. What was interesting, or what did you learn? A short paragraph here is fine.

# %% [markdown]
# `Your answer here.`
